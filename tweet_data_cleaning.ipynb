# %%
import numpy as np
import pandas as pd
import pickle
import re

# %%
with open('scotus_tweets_01_31.pkl', 'r') as picklefile: 
    tweets = pickle.load(picklefile)

# %%
status = tweets[0]

# %%
tweets_clean = [{'tweet_id': tweet.id,
                 'text': tweet.text,
                 'user_id': tweet.user.id,
                 'user_name': tweet.user.screen_name,
                 'name': tweet.user.name,
                 'bio': tweet.user.description,
                 'followers': tweet.user.followers_count,
                 'following': tweet.user.friends_count,
                 'symbols': tweet.entities['symbols'],
                 'mentions': tweet.entities['user_mentions'],
                 'hashtags': tweet.entities['hashtags'],
                 'urls': tweet.entities['urls'],
                 'retweeted': tweet.retweeted,
                 'geo': tweet.geo
                } for tweet in tweets[:10]]

# %%
tweets_clean
# Out:
# [{'bio': u'Music History Metal Politics',
#   'followers': 1243,
#   'following': 2731,
#   'geo': None,
#   'hashtags': [{u'indices': [130, 137], u'text': u'SCOTUS'}],
#   'mentions': [{u'id': 4224729994,
#     u'id_str': u'4224729994',
#     u'indices': [3, 11],
#     u'name': u'Tennessee',
#     u'screen_name': u'TEN_GOP'}],
#   'name': u'Northland Rebel',
#   'retweeted': False,
#   'symbols': [],
#   'text': u'RT @TEN_GOP: Dems lost the White House, Senate, House and 33 states in open elections, yet somehow feel they should be choosing a #SCOTUS j\u2026',
#   'tweet_id': 826596968294129664,
#   'urls': [],
#   'user_id': 800561690613977088,
#   'user_name': u'northlandrebel'},
#  {'bio': u'sarcastic grenade throwing Conservative #waar; #tcot....Stevie Nicks, STL Cardinals, enemy of the left, gymrat & beer snob',
#   'followers': 928,
#   'following': 917,
#   'geo': None,
#   'hashtags': [{u'indices': [0, 7], u'text': u'SCOTUS'}],
#   'mentions': [],
#   'name': u'William Allen',
#   'retweeted': False,
#   'symbols': [],
#   'text': u'#SCOTUS ... Gorsuch !',
#   'tweet_id': 826596967866318848,
#   'urls': [],
#   'user_id': 1431404118,
#   'user_name': u'WhamaaAllen'},
#  {'bio': u'jonathan cheban blocked me',
#   'followers': 403,
#   'following': 1609,
#   'geo': None,
#   'hashtags': [{u'indices': [38, 45], u'text': u'SCOTUS'}],
#   'mentions': [],
#   'name': u'dj horn',
#   'retweeted': False,
#   'symbols': [],
#   'text': u'"I am a man of my word"\n\nlol ok, 45 \n\n#SCOTUS',
#   'tweet_id': 826596967782481920,
#   'urls': [],
#   'user_id': 19366299,
#   'user_name': u'thedirtyderek'},
#  {'bio': u'Managing Editor of @YahooFinance. Making business news great again.',
#   'followers': 18181,
#   'following': 2430,
#   'geo': None,
#   'hashtags': [{u'indices': [24, 31], u'text': u'SCOTUS'}],
#   'mentions': [],
#   'name': u'Sam Ro',
#   'retweeted': False,
#   'symbols': [],
#   'text': u'Trump picks Gorsuch for #SCOTUS  https://t.co/KnVPEYL3kH',
#   'tweet_id': 826596967597932545,
#   'urls': [{u'display_url': u'yhoo.it/2kes1nj',
#     u'expanded_url': u'https://yhoo.it/2kes1nj',
#     u'indices': [33, 56],
#     u'url': u'https://t.co/KnVPEYL3kH'}],
#   'user_id': 239026022,
#   'user_name': u'bySamRo'},
#  {'bio': u'Lived, loved and worked in the City of spies.',
#   'followers': 138,
#   'following': 296,
#   'geo': None,
#   'hashtags': [{u'indices': [49, 56], u'text': u'scotus'},
#    {u'indices': [57, 70], u'text': u'supremecourt'}],
#   'mentions': [{u'id': 26671572,
#     u'id_str': u'26671572',
#     u'indices': [3, 14],
#     u'name': u'Paul Miller',
#     u'screen_name': u'MillerRoad'}],
#   'name': u'Zenn',
#   'retweeted': False,
#   'symbols': [],
#   'text': u'RT @MillerRoad: I missed the call-in numbers for #scotus #supremecourt',
#   'tweet_id': 826596967358803968,
#   'urls': [],
#   'user_id': 631552505,
#   'user_name': u'MzZenn'},
#  {'bio': u'#GOP Guy. GW Prof. - @GSPMgwu. Author. As Seen On TV. Contributor @USNewsOpinion & @thehill. @925FMFOXNews #MAGA',
#   'followers': 22721,
#   'following': 2520,
#   'geo': None,
#   'hashtags': [{u'indices': [82, 89], u'text': u'SCOTUS'}],
#   'mentions': [{u'id': 25073877,
#     u'id_str': u'25073877',
#     u'indices': [1, 17],
#     u'name': u'Donald J. Trump',
#     u'screen_name': u'realDonaldTrump'}],
#   'name': u"Ford O'Connell",
#   'retweeted': False,
#   'symbols': [],
#   'text': u'.@realDonaldTrump pays his debt to conservatives w/his selection of Neil Gorsuch! #SCOTUS',
#   'tweet_id': 826596966662623232,
#   'urls': [],
#   'user_id': 123899931,
#   'user_name': u'FordOConnell'},
#  {'bio': u'Video Reporter at @YahooNews w/ @KatieCouric reporting/tweeting about #news #business #STEM & #Hamilton. New York transplant. @MedillSchool Mafia. RTs\u2260Es, etc.',
#   'followers': 1194,
#   'following': 928,
#   'geo': None,
#   'hashtags': [{u'indices': [50, 57], u'text': u'SCOTUS'}],
#   'mentions': [],
#   'name': u'Summer Delaney',
#   'retweeted': False,
#   'symbols': [],
#   'text': u'BREAKING: Trump selects Judge Neil Gorsuch as his #SCOTUS pick',
#   'tweet_id': 826596966423461888,
#   'urls': [],
#   'user_id': 450397102,
#   'user_name': u'Summer_Delaney'},
#  {'bio': u'',
#   'followers': 1,
#   'following': 87,
#   'geo': None,
#   'hashtags': [{u'indices': [84, 91], u'text': u'SCOTUS'}],
#   'mentions': [{u'id': 19259102,
#     u'id_str': u'19259102',
#     u'indices': [3, 15],
#     u'name': u'Harvard Law School',
#     u'screen_name': u'Harvard_Law'},
#    {u'id': 991745802,
#     u'id_str': u'991745802',
#     u'indices': [38, 51],
#     u'name': u'Cass Sunstein',
#     u'screen_name': u'CassSunstein'},
#    {u'id': 227682918,
#     u'id_str': u'227682918',
#     u'indices': [56, 59],
#     u'name': u'Bloomberg View',
#     u'screen_name': u'BV'}],
#   'name': u'Marcus Paulo DaCunha',
#   'retweeted': False,
#   'symbols': [],
#   'text': u'RT @Harvard_Law: What is originalism? @CassSunstein via @BV https://t.co/vrRRDLlwhH #SCOTUS',
#   'tweet_id': 826596966159286272,
#   'urls': [{u'display_url': u'hvrdlaw.me/uykT308y6cc',
#     u'expanded_url': u'http://hvrdlaw.me/uykT308y6cc',
#     u'indices': [60, 83],
#     u'url': u'https://t.co/vrRRDLlwhH'}],
#   'user_id': 824335233545801731,
#   'user_name': u'marcuspcunha'},
#  {'bio': u'Bloomberg congressional and political reporter. Covering #SCOTUSNominee, #TheWall, variious other stuff.  Opinions my own. E-mail: llitvan@bloomberg.net',
#   'followers': 1607,
#   'following': 1190,
#   'geo': None,
#   'hashtags': [{u'indices': [14, 28], u'text': u'SCOTUSNominee'},
#    {u'indices': [29, 36], u'text': u'SCOTUS'}],
#   'mentions': [],
#   'name': u'Laura Litvan',
#   'retweeted': False,
#   'symbols': [],
#   'text': u"It's Gorsuch! #SCOTUSNominee #SCOTUS",
#   'tweet_id': 826596965953728512,
#   'urls': [],
#   'user_id': 313545488,
#   'user_name': u'LauraLitvan'},
#  {'bio': u'Feminist. Historian. I have Fibromyalgia and it sucks. Opinions are my own. #atxfem',
#   'followers': 1764,
#   'following': 599,
#   'geo': None,
#   'hashtags': [{u'indices': [25, 32], u'text': u'SCOTUS'}],
#   'mentions': [{u'id': 5447242,
#     u'id_str': u'5447242',
#     u'indices': [3, 13],
#     u'name': u'Emily Zanotti',
#     u'screen_name': u'emzanotti'}],
#   'name': u'Virginia in Texas',
#   'retweeted': False,
#   'symbols': [],
#   'text': u'RT @emzanotti: You guys, #SCOTUS is the missing bobcat and you know it.',
#   'tweet_id': 826596965886599169,
#   'urls': [],
#   'user_id': 188164477,
#   'user_name': u'TooTwistedTV'}]
